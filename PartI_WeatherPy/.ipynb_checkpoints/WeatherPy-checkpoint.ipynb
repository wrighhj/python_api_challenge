# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# 3 observables from WeatherPy data set:
# 1) temperature is higher at the equator
# 2) Humidity fluxates less around the equator. The graph of humidity vs latitude shows that there are areas at higher and lower latitudes that have much larger distribution of humidities (10%-100%) while around the equator the range is only (60%-100%)
# 3) The opposite could be said for wind speed and latitude. It seems like the closer to the equator you get the larger the range of windspeed between cities compared to cities at higher or lower latitudes.

# %%
# Dependencies and Setup
import json
import os
import random
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import csv

# Import API key
import config
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs, cities, and define temperature units
cities = []
lat_ngs = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
# If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
    
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# URL for Current Weather Data API Call

# save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
params = {'units': 'imperial',
          'appid': weather_api_key,
          'q': ''}

# %%
# Empty Lists to append API data to
city_name = []
temp = []
lat = []
lon = []
humidity = []
cloudiness = []
wind_speed = []
date = []
country = []

# Initialize a counter for the number of API calls
counter = 1

print(f"Beginning Data Retrieval")
print(f"--------------------------------")

#Loop through the cities in the cities_list 
for city in cities:
    try: 
        params['q'] = city
        response = requests.get(url, params=params).json()
        
        #start appending data to lists
        city_name.append(response["name"])
        temp.append(response["main"]["temp"])
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        date.append(response["dt"])
        country.append(response["sys"]["country"])
        city_counter = response["name"]
        
        # Increase counter by one 
        print(f"Processing Record {counter} | {city_counter}")
        print(f"{url}&q={city}")
        
        #increase counter by 1
        counter += 1
        
        
    #if no data for city, skip
    except KeyError:
        print(f"{city} not found: Skipping")
        
print("--------------------------------")
print(f"Weather data found for {len(cities)} cities.")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 | Husavik
# http://api.openweathermap.org/data/2.5/weather?&q=husavik
# Processing Record 2 | George Town
# http://api.openweathermap.org/data/2.5/weather?&q=georgetown
# Processing Record 3 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?&q=rikitea
# Processing Record 4 | Nabire
# http://api.openweathermap.org/data/2.5/weather?&q=nabire
# Processing Record 5 | Busselton
# http://api.openweathermap.org/data/2.5/weather?&q=busselton
# Processing Record 6 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?&q=mar del plata
# Processing Record 7 | Florianópolis
# http://api.openweathermap.org/data/2.5/weather?&q=florianopolis
# Processing Record 8 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?&q=qaanaaq
# Processing Record 9 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?&q=ushuaia
# haibowan not found: Skipping
# Processing Record 10 | Catió
# http://api.openweathermap.org/data/2.5/weather?&q=catio
# Processing Record 11 | Dongli
# http://api.openweathermap.org/data/2.5/weather?&q=dongli
# Processing Record 12 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?&q=geraldton
# Processing Record 13 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?&q=hermanus
# Processing Record 14 | Bilma
# http://api.openweathermap.org/data/2.5/weather?&q=bilma
# Processing Record 15 | Uyuni
# http://api.openweathermap.org/data/2.5/weather?&q=uyuni
# Processing Record 16 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?&q=pacific grove
# Processing Record 17 | Winnemucca
# http://api.openweathermap.org/data/2.5/weather?&q=winnemucca
# Processing Record 18 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?&q=tasiilaq
# Processing Record 19 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?&q=grindavik
# Processing Record 20 | Barra de Tecoanapa
# http://api.openweathermap.org/data/2.5/weather?&q=tecoanapa
# Processing Record 21 | Zduńska Wola
# http://api.openweathermap.org/data/2.5/weather?&q=zdunska wola
# Processing Record 22 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?&q=port elizabeth
# satitoa not found: Skipping
# Processing Record 23 | Halifax
# http://api.openweathermap.org/data/2.5/weather?&q=halifax
# Processing Record 24 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?&q=punta arenas
# karamay not found: Skipping
# galiwinku not found: Skipping
# Processing Record 25 | Bud
# http://api.openweathermap.org/data/2.5/weather?&q=bud
# Processing Record 26 | Hilo
# http://api.openweathermap.org/data/2.5/weather?&q=hilo
# alotau not found: Skipping
# Processing Record 27 | Joutseno
# http://api.openweathermap.org/data/2.5/weather?&q=joutseno
# Processing Record 28 | Maceió
# http://api.openweathermap.org/data/2.5/weather?&q=maceio
# Processing Record 29 | Kumul
# http://api.openweathermap.org/data/2.5/weather?&q=hami
# Processing Record 30 | Dikson
# http://api.openweathermap.org/data/2.5/weather?&q=dikson
# Processing Record 31 | Kurumkan
# http://api.openweathermap.org/data/2.5/weather?&q=kurumkan
# Processing Record 32 | Castro
# http://api.openweathermap.org/data/2.5/weather?&q=castro
# Processing Record 33 | Coolum Beach
# http://api.openweathermap.org/data/2.5/weather?&q=coolum beach
# Processing Record 34 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?&q=cidreira
# Processing Record 35 | Bend
# http://api.openweathermap.org/data/2.5/weather?&q=bend
# Processing Record 36 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?&q=jamestown
# Processing Record 37 | Todos Santos
# http://api.openweathermap.org/data/2.5/weather?&q=todos santos
# barentsburg not found: Skipping
# Processing Record 38 | Waipawa
# http://api.openweathermap.org/data/2.5/weather?&q=waipawa
# Processing Record 39 | Saint Paul Harbor
# http://api.openweathermap.org/data/2.5/weather?&q=kodiak
# Processing Record 40 | Poum
# http://api.openweathermap.org/data/2.5/weather?&q=poum
# Processing Record 41 | San Quintín
# http://api.openweathermap.org/data/2.5/weather?&q=san quintin
# Processing Record 42 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=hithadhoo
# Processing Record 43 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?&q=saint-philippe
# Processing Record 44 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?&q=new norfolk
# Processing Record 45 | Cooma
# http://api.openweathermap.org/data/2.5/weather?&q=cooma
# Processing Record 46 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?&q=cherskiy
# Processing Record 47 | Aykhal
# http://api.openweathermap.org/data/2.5/weather?&q=aykhal
# Processing Record 48 | Bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?&q=bambanglipuro
# Processing Record 49 | Ventspils
# http://api.openweathermap.org/data/2.5/weather?&q=ventspils
# Processing Record 50 | Semīrom
# http://api.openweathermap.org/data/2.5/weather?&q=semirom
# Processing Record 51 | Dareda
# http://api.openweathermap.org/data/2.5/weather?&q=dareda
# Processing Record 52 | Bluff
# http://api.openweathermap.org/data/2.5/weather?&q=bluff
# Processing Record 53 | Brae
# http://api.openweathermap.org/data/2.5/weather?&q=brae
# Processing Record 54 | Loíza
# http://api.openweathermap.org/data/2.5/weather?&q=loiza
# Processing Record 55 | Mataura
# http://api.openweathermap.org/data/2.5/weather?&q=mataura
# Processing Record 56 | Sorong
# http://api.openweathermap.org/data/2.5/weather?&q=sorong
# Processing Record 57 | Westport
# http://api.openweathermap.org/data/2.5/weather?&q=westport
# amderma not found: Skipping
# taolanaro not found: Skipping
# Processing Record 58 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?&q=port alfred
# Processing Record 59 | Barrow
# http://api.openweathermap.org/data/2.5/weather?&q=barrow
# Processing Record 60 | Albany
# http://api.openweathermap.org/data/2.5/weather?&q=albany
# qafsah not found: Skipping
# illoqqortoormiut not found: Skipping
# aflu not found: Skipping
# Processing Record 61 | Hohhot
# http://api.openweathermap.org/data/2.5/weather?&q=hohhot
# Processing Record 62 | Kamloops
# http://api.openweathermap.org/data/2.5/weather?&q=kamloops
# Processing Record 63 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?&q=pangnirtung
# Processing Record 64 | Vaini
# http://api.openweathermap.org/data/2.5/weather?&q=vaini
# Processing Record 65 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?&q=yellowknife
# Processing Record 66 | Sørland
# http://api.openweathermap.org/data/2.5/weather?&q=sorland
# Processing Record 67 | San Lorenzo
# http://api.openweathermap.org/data/2.5/weather?&q=san lorenzo
# Processing Record 68 | Faya
# http://api.openweathermap.org/data/2.5/weather?&q=faya
# Processing Record 69 | Khani
# http://api.openweathermap.org/data/2.5/weather?&q=khani
# Processing Record 70 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?&q=saint anthony
# Processing Record 71 | Airai
# http://api.openweathermap.org/data/2.5/weather?&q=airai
# Processing Record 72 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?&q=kavieng
# Processing Record 73 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?&q=vila velha
# ayer itam not found: Skipping
# umzimvubu not found: Skipping
# Processing Record 74 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?&q=clyde river
# Processing Record 75 | Bethel
# http://api.openweathermap.org/data/2.5/weather?&q=bethel
# Processing Record 76 | Oodweyne
# http://api.openweathermap.org/data/2.5/weather?&q=odweyne
# Processing Record 77 | Vanderhoof
# http://api.openweathermap.org/data/2.5/weather?&q=vanderhoof
# Processing Record 78 | Santa Cruz de la Sierra
# http://api.openweathermap.org/data/2.5/weather?&q=santa cruz
# Processing Record 79 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?&q=tiksi
# Processing Record 80 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?&q=beringovskiy
# fort saint john not found: Skipping
# Processing Record 81 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?&q=arraial do cabo
# Processing Record 82 | Tautira
# http://api.openweathermap.org/data/2.5/weather?&q=tautira
# Processing Record 83 | Río Gallegos
# http://api.openweathermap.org/data/2.5/weather?&q=rio gallegos
# Processing Record 84 | Raton
# http://api.openweathermap.org/data/2.5/weather?&q=raton
# Processing Record 85 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?&q=katsuura
# Processing Record 86 | Batemans Bay
# http://api.openweathermap.org/data/2.5/weather?&q=batemans bay
# Processing Record 87 | Pisco
# http://api.openweathermap.org/data/2.5/weather?&q=pisco
# Processing Record 88 | Avarua
# http://api.openweathermap.org/data/2.5/weather?&q=avarua
# Processing Record 89 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?&q=kapaa
# Processing Record 90 | Aksarka
# http://api.openweathermap.org/data/2.5/weather?&q=aksarka
# Processing Record 91 | Bhag
# http://api.openweathermap.org/data/2.5/weather?&q=bhag
# Processing Record 92 | Marawi
# http://api.openweathermap.org/data/2.5/weather?&q=marawi
# Processing Record 93 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?&q=nuuk
# Processing Record 94 | Mahébourg
# http://api.openweathermap.org/data/2.5/weather?&q=mahebourg
# Processing Record 95 | Novyy Urgal
# http://api.openweathermap.org/data/2.5/weather?&q=novyy urgal
# Processing Record 96 | Teberda
# http://api.openweathermap.org/data/2.5/weather?&q=teberda
# Processing Record 97 | Vardø
# http://api.openweathermap.org/data/2.5/weather?&q=vardo
# mrirt not found: Skipping
# Processing Record 98 | Constitución
# http://api.openweathermap.org/data/2.5/weather?&q=constitucion
# Processing Record 99 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?&q=coquimbo
# Processing Record 100 | Souillac
# http://api.openweathermap.org/data/2.5/weather?&q=souillac
# Processing Record 101 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?&q=chokurdakh
# Processing Record 102 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?&q=san patricio
# Processing Record 103 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?&q=nikolskoye
# Processing Record 104 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?&q=khatanga
# Processing Record 105 | Elk Plain
# http://api.openweathermap.org/data/2.5/weather?&q=elk plain
# Processing Record 106 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?&q=tuktoyaktuk
# Processing Record 107 | Quesnel
# http://api.openweathermap.org/data/2.5/weather?&q=quesnel
# Processing Record 108 | Maţāy
# http://api.openweathermap.org/data/2.5/weather?&q=matay
# Processing Record 109 | Pāvilosta
# http://api.openweathermap.org/data/2.5/weather?&q=pavilosta
# Processing Record 110 | Bonthe
# http://api.openweathermap.org/data/2.5/weather?&q=bonthe
# Processing Record 111 | Faanui
# http://api.openweathermap.org/data/2.5/weather?&q=faanui
# Processing Record 112 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?&q=makakilo city
# Processing Record 113 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?&q=ribeira grande
# warqla not found: Skipping
# Processing Record 114 | Huarmey
# http://api.openweathermap.org/data/2.5/weather?&q=huarmey
# Processing Record 115 | Mayor Pablo Lagerenza
# http://api.openweathermap.org/data/2.5/weather?&q=mayor pablo lagerenza
# Processing Record 116 | Zabrat
# http://api.openweathermap.org/data/2.5/weather?&q=zabrat
# Processing Record 117 | Korla
# http://api.openweathermap.org/data/2.5/weather?&q=korla
# Processing Record 118 | Bom Jesus da Lapa
# http://api.openweathermap.org/data/2.5/weather?&q=bom jesus da lapa
# Processing Record 119 | Sistranda
# http://api.openweathermap.org/data/2.5/weather?&q=sistranda
# Processing Record 120 | Gōtsuchō
# http://api.openweathermap.org/data/2.5/weather?&q=gotsu
# utiroa not found: Skipping
# Processing Record 121 | Arrondissement de Bressuire
# http://api.openweathermap.org/data/2.5/weather?&q=bressuire
# Processing Record 122 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?&q=bathsheba
# tumannyy not found: Skipping
# belushya guba not found: Skipping
# Processing Record 123 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?&q=puerto ayora
# Processing Record 124 | Sitka
# http://api.openweathermap.org/data/2.5/weather?&q=sitka
# Processing Record 125 | Yenagoa
# http://api.openweathermap.org/data/2.5/weather?&q=yenagoa
# Processing Record 126 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?&q=los llanos de aridane
# Processing Record 127 | Hondomachi-hondo
# http://api.openweathermap.org/data/2.5/weather?&q=hondo
# Processing Record 128 | Chadan
# http://api.openweathermap.org/data/2.5/weather?&q=chadan
# Processing Record 129 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?&q=san cristobal
# Processing Record 130 | Atuona
# http://api.openweathermap.org/data/2.5/weather?&q=atuona
# Processing Record 131 | Usinsk
# http://api.openweathermap.org/data/2.5/weather?&q=usinsk
# Processing Record 132 | Urucará
# http://api.openweathermap.org/data/2.5/weather?&q=urucara
# Processing Record 133 | Harbour Breton
# http://api.openweathermap.org/data/2.5/weather?&q=harbour breton
# vaitupu not found: Skipping
# Processing Record 134 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?&q=ahipara
# Processing Record 135 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?&q=narsaq
# Processing Record 136 | Sosnogorsk
# http://api.openweathermap.org/data/2.5/weather?&q=sosnogorsk
# Processing Record 137 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?&q=iqaluit
# Processing Record 138 | Codrington
# http://api.openweathermap.org/data/2.5/weather?&q=codrington
# Processing Record 139 | Thinadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=thinadhoo
# Processing Record 140 | Broome
# http://api.openweathermap.org/data/2.5/weather?&q=broome
# Processing Record 141 | Jiaocheng
# http://api.openweathermap.org/data/2.5/weather?&q=jiaocheng
# Processing Record 142 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?&q=bredasdorp
# Processing Record 143 | Belaya Gora
# http://api.openweathermap.org/data/2.5/weather?&q=belaya gora
# Processing Record 144 | Maningrida
# http://api.openweathermap.org/data/2.5/weather?&q=maningrida
# Processing Record 145 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?&q=paamiut
# Processing Record 146 | Umm Kaddadah
# http://api.openweathermap.org/data/2.5/weather?&q=umm kaddadah
# Processing Record 147 | Bengkulu
# http://api.openweathermap.org/data/2.5/weather?&q=bengkulu
# Processing Record 148 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?&q=upernavik
# Processing Record 149 | Nīlēshwar
# http://api.openweathermap.org/data/2.5/weather?&q=nileshwar
# Processing Record 150 | Bairiki Village
# http://api.openweathermap.org/data/2.5/weather?&q=bairiki
# Processing Record 151 | Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?&q=petropavlovsk-kamchatskiy
# Processing Record 152 | Urubichá
# http://api.openweathermap.org/data/2.5/weather?&q=urubicha
# tsihombe not found: Skipping
# a not found: Skipping
# Processing Record 153 | Eganville
# http://api.openweathermap.org/data/2.5/weather?&q=eganville
# ijaki not found: Skipping
# Processing Record 154 | Mocajuba
# http://api.openweathermap.org/data/2.5/weather?&q=mocajuba
# Processing Record 155 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?&q=carnarvon
# Processing Record 156 | Lapi
# http://api.openweathermap.org/data/2.5/weather?&q=lapi
# Processing Record 157 | Severo-Kuril'sk
# http://api.openweathermap.org/data/2.5/weather?&q=severo-kurilsk
# Processing Record 158 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?&q=provideniya
# Processing Record 159 | Coração de Maria
# http://api.openweathermap.org/data/2.5/weather?&q=coracao de maria
# Processing Record 160 | São João da Barra
# http://api.openweathermap.org/data/2.5/weather?&q=sao joao da barra
# Processing Record 161 | Laguna
# http://api.openweathermap.org/data/2.5/weather?&q=laguna
# Processing Record 162 | Hobart
# http://api.openweathermap.org/data/2.5/weather?&q=hobart
# Processing Record 163 | Praia da Vitória
# http://api.openweathermap.org/data/2.5/weather?&q=praia da vitoria
# burica not found: Skipping
# marcona not found: Skipping
# Processing Record 164 | Lashio
# http://api.openweathermap.org/data/2.5/weather?&q=lashio
# Processing Record 165 | Mana
# http://api.openweathermap.org/data/2.5/weather?&q=mana
# Processing Record 166 | Deputatsky
# http://api.openweathermap.org/data/2.5/weather?&q=deputatskiy
# Processing Record 167 | Tezu
# http://api.openweathermap.org/data/2.5/weather?&q=tezu
# Processing Record 168 | El Alto
# http://api.openweathermap.org/data/2.5/weather?&q=el alto
# afgoye not found: Skipping
# Processing Record 169 | Salalah
# http://api.openweathermap.org/data/2.5/weather?&q=salalah
# Processing Record 170 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?&q=cabo san lucas
# Processing Record 171 | Sechura
# http://api.openweathermap.org/data/2.5/weather?&q=sechura
# Processing Record 172 | Balakhta
# http://api.openweathermap.org/data/2.5/weather?&q=balakhta
# Processing Record 173 | Muravlenko
# http://api.openweathermap.org/data/2.5/weather?&q=muravlenko
# Processing Record 174 | Vanavara
# http://api.openweathermap.org/data/2.5/weather?&q=vanavara
# Processing Record 175 | Kantang
# http://api.openweathermap.org/data/2.5/weather?&q=kantang
# Processing Record 176 | Bānposh
# http://api.openweathermap.org/data/2.5/weather?&q=banposh
# Processing Record 177 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?&q=kruisfontein
# Processing Record 178 | Anloga
# http://api.openweathermap.org/data/2.5/weather?&q=anloga
# Processing Record 179 | Grand Bois
# http://api.openweathermap.org/data/2.5/weather?&q=grand bois
# Processing Record 180 | Erenhot
# http://api.openweathermap.org/data/2.5/weather?&q=erenhot
# Processing Record 181 | Soma
# http://api.openweathermap.org/data/2.5/weather?&q=soma
# Processing Record 182 | Bulgan
# http://api.openweathermap.org/data/2.5/weather?&q=bulgan
# attawapiskat not found: Skipping
# Processing Record 183 | Constantine
# http://api.openweathermap.org/data/2.5/weather?&q=constantine
# Processing Record 184 | Ixtapa
# http://api.openweathermap.org/data/2.5/weather?&q=ixtapa
# Processing Record 185 | Dzilam González
# http://api.openweathermap.org/data/2.5/weather?&q=dzilam gonzalez
# Processing Record 186 | Dover
# http://api.openweathermap.org/data/2.5/weather?&q=dover
# Processing Record 187 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?&q=port blair
# Processing Record 188 | Pflugerville
# http://api.openweathermap.org/data/2.5/weather?&q=pflugerville
# Processing Record 189 | Kyren
# http://api.openweathermap.org/data/2.5/weather?&q=kyren
# Processing Record 190 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?&q=norman wells
# Processing Record 191 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?&q=saldanha
# Processing Record 192 | Marsá Maţrūḩ
# http://api.openweathermap.org/data/2.5/weather?&q=marsa matruh
# Processing Record 193 | Taltal
# http://api.openweathermap.org/data/2.5/weather?&q=taltal
# sentyabrskiy not found: Skipping
# samusu not found: Skipping
# Processing Record 194 | Bereket
# http://api.openweathermap.org/data/2.5/weather?&q=gazanjyk
# Processing Record 195 | Lebu
# http://api.openweathermap.org/data/2.5/weather?&q=lebu
# Processing Record 196 | Viedma
# http://api.openweathermap.org/data/2.5/weather?&q=viedma
# Processing Record 197 | Kahului
# http://api.openweathermap.org/data/2.5/weather?&q=kahului
# Processing Record 198 | Newport
# http://api.openweathermap.org/data/2.5/weather?&q=newport
# Processing Record 199 | Vorobyevka
# http://api.openweathermap.org/data/2.5/weather?&q=vorobyevka
# Processing Record 200 | Saint George
# http://api.openweathermap.org/data/2.5/weather?&q=saint george
# Processing Record 201 | Green River
# http://api.openweathermap.org/data/2.5/weather?&q=green river
# Processing Record 202 | Osorno
# http://api.openweathermap.org/data/2.5/weather?&q=osorno
# Processing Record 203 | Atar
# http://api.openweathermap.org/data/2.5/weather?&q=atar
# Processing Record 204 | Youghal
# http://api.openweathermap.org/data/2.5/weather?&q=youghal
# nguiu not found: Skipping
# Processing Record 205 | Amazar
# http://api.openweathermap.org/data/2.5/weather?&q=amazar
# Processing Record 206 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?&q=egvekinot
# Processing Record 207 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?&q=cape town
# Processing Record 208 | Correntina
# http://api.openweathermap.org/data/2.5/weather?&q=correntina
# Processing Record 209 | Ancud
# http://api.openweathermap.org/data/2.5/weather?&q=ancud
# Processing Record 210 | Liepāja
# http://api.openweathermap.org/data/2.5/weather?&q=liepaja
# Processing Record 211 | Tazovsky
# http://api.openweathermap.org/data/2.5/weather?&q=tazovskiy
# bolungarvik not found: Skipping
# Processing Record 212 | Banda Aceh
# http://api.openweathermap.org/data/2.5/weather?&q=banda aceh
# Processing Record 213 | Duvan
# http://api.openweathermap.org/data/2.5/weather?&q=duvan
# saleaula not found: Skipping
# Processing Record 214 | Antofagasta
# http://api.openweathermap.org/data/2.5/weather?&q=antofagasta
# Processing Record 215 | Basco
# http://api.openweathermap.org/data/2.5/weather?&q=basco
# Processing Record 216 | Mossamedes
# http://api.openweathermap.org/data/2.5/weather?&q=namibe
# Processing Record 217 | Wajima
# http://api.openweathermap.org/data/2.5/weather?&q=wajima
# cheuskiny not found: Skipping
# Processing Record 218 | Gizo Government Station
# http://api.openweathermap.org/data/2.5/weather?&q=gizo
# Processing Record 219 | Hong Kong
# http://api.openweathermap.org/data/2.5/weather?&q=victoria
# Processing Record 220 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?&q=lavrentiya
# Processing Record 221 | Roald
# http://api.openweathermap.org/data/2.5/weather?&q=roald
# Processing Record 222 | Araguaçu
# http://api.openweathermap.org/data/2.5/weather?&q=araguacu
# maisuru not found: Skipping
# Processing Record 223 | Ghanzi
# http://api.openweathermap.org/data/2.5/weather?&q=ghanzi
# Processing Record 224 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?&q=sioux lookout
# Processing Record 225 | Magangué
# http://api.openweathermap.org/data/2.5/weather?&q=magangue
# Processing Record 226 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?&q=nanortalik
# Processing Record 227 | Mogadishu
# http://api.openweathermap.org/data/2.5/weather?&q=mogadishu
# Processing Record 228 | Vostok
# http://api.openweathermap.org/data/2.5/weather?&q=vostok
# Processing Record 229 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?&q=ponta do sol
# Processing Record 230 | Birjand
# http://api.openweathermap.org/data/2.5/weather?&q=birjand
# Processing Record 231 | São José da Coroa Grande
# http://api.openweathermap.org/data/2.5/weather?&q=sao jose da coroa grande
# Processing Record 232 | Berlevåg
# http://api.openweathermap.org/data/2.5/weather?&q=berlevag
# Processing Record 233 | Camacha
# http://api.openweathermap.org/data/2.5/weather?&q=camacha
# Processing Record 234 | Inta
# http://api.openweathermap.org/data/2.5/weather?&q=inta
# Processing Record 235 | Nome
# http://api.openweathermap.org/data/2.5/weather?&q=nome
# rungata not found: Skipping
# Processing Record 236 | Rocha
# http://api.openweathermap.org/data/2.5/weather?&q=rocha
# Processing Record 237 | Dawlatabad
# http://api.openweathermap.org/data/2.5/weather?&q=dawlatabad
# Processing Record 238 | Coahuayana Viejo
# http://api.openweathermap.org/data/2.5/weather?&q=coahuayana
# Processing Record 239 | Whitianga
# http://api.openweathermap.org/data/2.5/weather?&q=whitianga
# Processing Record 240 | Baykit
# http://api.openweathermap.org/data/2.5/weather?&q=baykit
# Processing Record 241 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?&q=fortuna
# Processing Record 242 | Kavalerovo
# http://api.openweathermap.org/data/2.5/weather?&q=kavalerovo
# Processing Record 243 | Rio Pardo de Minas
# http://api.openweathermap.org/data/2.5/weather?&q=rio pardo de minas
# Processing Record 244 | Xining
# http://api.openweathermap.org/data/2.5/weather?&q=xining
# Processing Record 245 | Guarapari
# http://api.openweathermap.org/data/2.5/weather?&q=guarapari
# Processing Record 246 | Chui
# http://api.openweathermap.org/data/2.5/weather?&q=chuy
# Processing Record 247 | Yarim
# http://api.openweathermap.org/data/2.5/weather?&q=yarim
# Processing Record 248 | Olafsvik
# http://api.openweathermap.org/data/2.5/weather?&q=olafsvik
# Processing Record 249 | Mogocha
# http://api.openweathermap.org/data/2.5/weather?&q=mogocha
# Processing Record 250 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?&q=butaritari
# Processing Record 251 | Aksu
# http://api.openweathermap.org/data/2.5/weather?&q=aksu
# Processing Record 252 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?&q=bandarbeyla
# Processing Record 253 | Kieta
# http://api.openweathermap.org/data/2.5/weather?&q=kieta
# Processing Record 254 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?&q=talnakh
# Processing Record 255 | Warwick
# http://api.openweathermap.org/data/2.5/weather?&q=warwick
# Processing Record 256 | Tilichiki
# http://api.openweathermap.org/data/2.5/weather?&q=tilichiki
# Processing Record 257 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?&q=hambantota
# Processing Record 258 | College
# http://api.openweathermap.org/data/2.5/weather?&q=college
# Processing Record 259 | Uíge
# http://api.openweathermap.org/data/2.5/weather?&q=uige
# malwan not found: Skipping
# Processing Record 260 | Araouane
# http://api.openweathermap.org/data/2.5/weather?&q=araouane
# Processing Record 261 | Camaná
# http://api.openweathermap.org/data/2.5/weather?&q=camana
# Processing Record 262 | Cotonou
# http://api.openweathermap.org/data/2.5/weather?&q=cotonou
# Processing Record 263 | Empalme
# http://api.openweathermap.org/data/2.5/weather?&q=empalme
# kuche not found: Skipping
# Processing Record 264 | Lodja
# http://api.openweathermap.org/data/2.5/weather?&q=lodja
# Processing Record 265 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?&q=tessalit
# Processing Record 266 | Gaurela
# http://api.openweathermap.org/data/2.5/weather?&q=gaurela
# Processing Record 267 | Sikonge
# http://api.openweathermap.org/data/2.5/weather?&q=sikonge
# Processing Record 268 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?&q=lompoc
# Processing Record 269 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?&q=hamilton
# Processing Record 270 | Walvis Bay
# http://api.openweathermap.org/data/2.5/weather?&q=walvis bay
# inderborskiy not found: Skipping
# Processing Record 271 | Laas
# http://api.openweathermap.org/data/2.5/weather?&q=lasa
# Processing Record 272 | Zeya
# http://api.openweathermap.org/data/2.5/weather?&q=zeya
# Processing Record 273 | East London
# http://api.openweathermap.org/data/2.5/weather?&q=east london
# Processing Record 274 | Bontang
# http://api.openweathermap.org/data/2.5/weather?&q=bontang
# Processing Record 275 | Methóni
# http://api.openweathermap.org/data/2.5/weather?&q=methoni
# Processing Record 276 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?&q=tuatapere
# Processing Record 277 | Flinders
# http://api.openweathermap.org/data/2.5/weather?&q=flinders
# Processing Record 278 | Nemours
# http://api.openweathermap.org/data/2.5/weather?&q=nemours
# Processing Record 279 | Yorosso
# http://api.openweathermap.org/data/2.5/weather?&q=yorosso
# Processing Record 280 | Cajazeiras
# http://api.openweathermap.org/data/2.5/weather?&q=cajazeiras
# Processing Record 281 | Abhā
# http://api.openweathermap.org/data/2.5/weather?&q=abha
# Processing Record 282 | Havøysund
# http://api.openweathermap.org/data/2.5/weather?&q=havoysund
# Processing Record 283 | Sainte-Maxime
# http://api.openweathermap.org/data/2.5/weather?&q=sainte-maxime
# Processing Record 284 | Srandakan
# http://api.openweathermap.org/data/2.5/weather?&q=srandakan
# Processing Record 285 | Wanning
# http://api.openweathermap.org/data/2.5/weather?&q=wanning
# Processing Record 286 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?&q=hualmay
# Processing Record 287 | Vao
# http://api.openweathermap.org/data/2.5/weather?&q=vao
# artyk not found: Skipping
# Processing Record 288 | Ust-Maya
# http://api.openweathermap.org/data/2.5/weather?&q=ust-maya
# Processing Record 289 | Alta
# http://api.openweathermap.org/data/2.5/weather?&q=alta
# Processing Record 290 | Shache
# http://api.openweathermap.org/data/2.5/weather?&q=shache
# Processing Record 291 | Tevaitoa
# http://api.openweathermap.org/data/2.5/weather?&q=tevaitoa
# Processing Record 292 | Baijiantan
# http://api.openweathermap.org/data/2.5/weather?&q=baijiantan
# grand river south east not found: Skipping
# Processing Record 293 | Erzin
# http://api.openweathermap.org/data/2.5/weather?&q=erzin
# Processing Record 294 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?&q=kununurra
# Processing Record 295 | Kamenka
# http://api.openweathermap.org/data/2.5/weather?&q=kamenka
# Processing Record 296 | Mandera
# http://api.openweathermap.org/data/2.5/weather?&q=mandera
# Processing Record 297 | Tālcher
# http://api.openweathermap.org/data/2.5/weather?&q=talcher
# Processing Record 298 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?&q=port hardy
# Processing Record 299 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?&q=hasaki
# Processing Record 300 | Moranbah
# http://api.openweathermap.org/data/2.5/weather?&q=moranbah
# Processing Record 301 | Burgos
# http://api.openweathermap.org/data/2.5/weather?&q=burgos
# Processing Record 302 | Belle Fourche
# http://api.openweathermap.org/data/2.5/weather?&q=belle fourche
# Processing Record 303 | Seminole
# http://api.openweathermap.org/data/2.5/weather?&q=seminole
# Processing Record 304 | Cabedelo
# http://api.openweathermap.org/data/2.5/weather?&q=cabedelo
# Processing Record 305 | Jetpur
# http://api.openweathermap.org/data/2.5/weather?&q=jetpur
# Processing Record 306 | Ulaanbaatar
# http://api.openweathermap.org/data/2.5/weather?&q=ulaanbaatar
# Processing Record 307 | Āmli
# http://api.openweathermap.org/data/2.5/weather?&q=amli
# Processing Record 308 | Tanete
# http://api.openweathermap.org/data/2.5/weather?&q=tanete
# Processing Record 309 | Plátanos
# http://api.openweathermap.org/data/2.5/weather?&q=platanos
# Processing Record 310 | Freetown
# http://api.openweathermap.org/data/2.5/weather?&q=freetown
# Processing Record 311 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?&q=saint-augustin
# Processing Record 312 | Byron Bay
# http://api.openweathermap.org/data/2.5/weather?&q=byron bay
# Processing Record 313 | Tegul'det
# http://api.openweathermap.org/data/2.5/weather?&q=teguldet
# Processing Record 314 | Goderich
# http://api.openweathermap.org/data/2.5/weather?&q=goderich
# Processing Record 315 | Wencheng
# http://api.openweathermap.org/data/2.5/weather?&q=wencheng
# Processing Record 316 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?&q=ilulissat
# Processing Record 317 | Fes
# http://api.openweathermap.org/data/2.5/weather?&q=fez
# vreed en hoop not found: Skipping
# macaboboni not found: Skipping
# Processing Record 318 | Baisha
# http://api.openweathermap.org/data/2.5/weather?&q=baisha
# Processing Record 319 | Talara
# http://api.openweathermap.org/data/2.5/weather?&q=talara
# Processing Record 320 | Abidjan
# http://api.openweathermap.org/data/2.5/weather?&q=abidjan
# Processing Record 321 | Chunskiy
# http://api.openweathermap.org/data/2.5/weather?&q=chunskiy
# Processing Record 322 | Skibbereen
# http://api.openweathermap.org/data/2.5/weather?&q=skibbereen
# Processing Record 323 | Moose Factory
# http://api.openweathermap.org/data/2.5/weather?&q=moose factory
# Processing Record 324 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?&q=vanimo
# Processing Record 325 | Alta Floresta
# http://api.openweathermap.org/data/2.5/weather?&q=alta floresta
# Processing Record 326 | Tucuruí
# http://api.openweathermap.org/data/2.5/weather?&q=tucurui
# Processing Record 327 | Kurchum
# http://api.openweathermap.org/data/2.5/weather?&q=kurchum
# Processing Record 328 | Biłgoraj
# http://api.openweathermap.org/data/2.5/weather?&q=bilgoraj
# Processing Record 329 | Myitkyina
# http://api.openweathermap.org/data/2.5/weather?&q=myitkyina
# Processing Record 330 | Nador
# http://api.openweathermap.org/data/2.5/weather?&q=nador
# Processing Record 331 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?&q=mount gambier
# Processing Record 332 | Sur
# http://api.openweathermap.org/data/2.5/weather?&q=sur
# Processing Record 333 | Nishihara
# http://api.openweathermap.org/data/2.5/weather?&q=nishihara
# Processing Record 334 | Finnsnes
# http://api.openweathermap.org/data/2.5/weather?&q=finnsnes
# Processing Record 335 | Esso
# http://api.openweathermap.org/data/2.5/weather?&q=esso
# Processing Record 336 | Bowling Green
# http://api.openweathermap.org/data/2.5/weather?&q=bowling green
# nizhneyansk not found: Skipping
# Processing Record 337 | Karratha
# http://api.openweathermap.org/data/2.5/weather?&q=karratha
# Processing Record 338 | Skjervøy
# http://api.openweathermap.org/data/2.5/weather?&q=skjervoy
# Processing Record 339 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?&q=vila franca do campo
# viligili not found: Skipping
# Processing Record 340 | Vyazemskiy
# http://api.openweathermap.org/data/2.5/weather?&q=vyazemskiy
# Processing Record 341 | Henties Bay
# http://api.openweathermap.org/data/2.5/weather?&q=henties bay
# Processing Record 342 | Merauke
# http://api.openweathermap.org/data/2.5/weather?&q=merauke
# Processing Record 343 | Kattivākkam
# http://api.openweathermap.org/data/2.5/weather?&q=kattivakkam
# Processing Record 344 | Carbonia
# http://api.openweathermap.org/data/2.5/weather?&q=carbonia
# Processing Record 345 | Emba
# http://api.openweathermap.org/data/2.5/weather?&q=emba
# Processing Record 346 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?&q=zhigansk
# Processing Record 347 | Evensk
# http://api.openweathermap.org/data/2.5/weather?&q=evensk
# Processing Record 348 | Wajir
# http://api.openweathermap.org/data/2.5/weather?&q=wajir
# Processing Record 349 | Pecos
# http://api.openweathermap.org/data/2.5/weather?&q=pecos
# Processing Record 350 | Sept-Îles
# http://api.openweathermap.org/data/2.5/weather?&q=sept-iles
# Processing Record 351 | Røros
# http://api.openweathermap.org/data/2.5/weather?&q=roros
# Processing Record 352 | Opuwo
# http://api.openweathermap.org/data/2.5/weather?&q=opuwo
# Processing Record 353 | Malaut
# http://api.openweathermap.org/data/2.5/weather?&q=malaut
# Processing Record 354 | Sinnamary
# http://api.openweathermap.org/data/2.5/weather?&q=sinnamary
# hihifo not found: Skipping
# Processing Record 355 | Iwanai
# http://api.openweathermap.org/data/2.5/weather?&q=iwanai
# Processing Record 356 | Guérande
# http://api.openweathermap.org/data/2.5/weather?&q=guerande
# rawannawi not found: Skipping
# Processing Record 357 | Tongliao
# http://api.openweathermap.org/data/2.5/weather?&q=tongliao
# Processing Record 358 | Banff
# http://api.openweathermap.org/data/2.5/weather?&q=banff
# lolua not found: Skipping
# Processing Record 359 | Vale da Amoreira
# http://api.openweathermap.org/data/2.5/weather?&q=vale da amoreira
# Processing Record 360 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?&q=maniitsoq
# Processing Record 361 | Mayskiy
# http://api.openweathermap.org/data/2.5/weather?&q=mayskiy
# Processing Record 362 | Donegal
# http://api.openweathermap.org/data/2.5/weather?&q=donegal
# Processing Record 363 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?&q=mehamn
# Processing Record 364 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?&q=haines junction
# Processing Record 365 | Thompson
# http://api.openweathermap.org/data/2.5/weather?&q=thompson
# Processing Record 366 | Bac Lieu
# http://api.openweathermap.org/data/2.5/weather?&q=bac lieu
# Processing Record 367 | Partizanskoye
# http://api.openweathermap.org/data/2.5/weather?&q=partizanskoye
# Processing Record 368 | Vernon
# http://api.openweathermap.org/data/2.5/weather?&q=vernon
# Processing Record 369 | Ayamé
# http://api.openweathermap.org/data/2.5/weather?&q=ayame
# Processing Record 370 | Show Low
# http://api.openweathermap.org/data/2.5/weather?&q=show low
# Processing Record 371 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?&q=kaitangata
# Processing Record 372 | Ozernovskiy
# http://api.openweathermap.org/data/2.5/weather?&q=ozernovskiy
# Processing Record 373 | Mananjary
# http://api.openweathermap.org/data/2.5/weather?&q=mananjary
# Processing Record 374 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?&q=ostrovnoy
# Processing Record 375 | Akureyri
# http://api.openweathermap.org/data/2.5/weather?&q=akureyri
# Processing Record 376 | Jasper
# http://api.openweathermap.org/data/2.5/weather?&q=jasper
# Processing Record 377 | Hede
# http://api.openweathermap.org/data/2.5/weather?&q=hede
# Processing Record 378 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?&q=alice springs
# Processing Record 379 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?&q=longyearbyen
# Processing Record 380 | Pioner
# http://api.openweathermap.org/data/2.5/weather?&q=pioner
# Processing Record 381 | Rio Grande
# http://api.openweathermap.org/data/2.5/weather?&q=rio grande
# Processing Record 382 | Kohlu
# http://api.openweathermap.org/data/2.5/weather?&q=kohlu
# Processing Record 383 | Torbay
# http://api.openweathermap.org/data/2.5/weather?&q=torbay
# Processing Record 384 | Assaí
# http://api.openweathermap.org/data/2.5/weather?&q=assai
# Processing Record 385 | Kholodnyy
# http://api.openweathermap.org/data/2.5/weather?&q=kholodnyy
# Processing Record 386 | Celestún
# http://api.openweathermap.org/data/2.5/weather?&q=celestun
# Processing Record 387 | Bilibino
# http://api.openweathermap.org/data/2.5/weather?&q=bilibino
# Processing Record 388 | Vung Tau
# http://api.openweathermap.org/data/2.5/weather?&q=vung tau
# Processing Record 389 | Ayagoz
# http://api.openweathermap.org/data/2.5/weather?&q=ayagoz
# Processing Record 390 | Morón
# http://api.openweathermap.org/data/2.5/weather?&q=moron
# Processing Record 391 | Gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?&q=gornopravdinsk
# Processing Record 392 | Ridgecrest
# http://api.openweathermap.org/data/2.5/weather?&q=ridgecrest
# Processing Record 393 | Barabai
# http://api.openweathermap.org/data/2.5/weather?&q=barabai
# Processing Record 394 | Richards Bay
# http://api.openweathermap.org/data/2.5/weather?&q=richards bay
# Processing Record 395 | Rapid City
# http://api.openweathermap.org/data/2.5/weather?&q=rapid city
# Processing Record 396 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?&q=bambous virieux
# Processing Record 397 | Shingū
# http://api.openweathermap.org/data/2.5/weather?&q=shingu
# Processing Record 398 | Namie
# http://api.openweathermap.org/data/2.5/weather?&q=namie
# Processing Record 399 | Şurmān
# http://api.openweathermap.org/data/2.5/weather?&q=surman
# Processing Record 400 | Stokmarknes
# http://api.openweathermap.org/data/2.5/weather?&q=stokmarknes
# Processing Record 401 | Vangaindrano
# http://api.openweathermap.org/data/2.5/weather?&q=vangaindrano
# Processing Record 402 | Dārāb
# http://api.openweathermap.org/data/2.5/weather?&q=darab
# Processing Record 403 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?&q=ambilobe
# Processing Record 404 | Japura
# http://api.openweathermap.org/data/2.5/weather?&q=japura
# Processing Record 405 | Jiwani
# http://api.openweathermap.org/data/2.5/weather?&q=jiwani
# Processing Record 406 | Sinazongwe
# http://api.openweathermap.org/data/2.5/weather?&q=sinazongwe
# Processing Record 407 | Sulangan
# http://api.openweathermap.org/data/2.5/weather?&q=sulangan
# tarudant not found: Skipping
# kollumerland not found: Skipping
# Processing Record 408 | Padang
# http://api.openweathermap.org/data/2.5/weather?&q=padang
# armacao dos buzios not found: Skipping
# Processing Record 409 | Simplício Mendes
# http://api.openweathermap.org/data/2.5/weather?&q=simplicio mendes
# Processing Record 410 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?&q=saskylakh
# Processing Record 411 | Dubbo
# http://api.openweathermap.org/data/2.5/weather?&q=dubbo
# Processing Record 412 | Mazyr
# http://api.openweathermap.org/data/2.5/weather?&q=mazyr
# Processing Record 413 | Lewistown
# http://api.openweathermap.org/data/2.5/weather?&q=lewistown
# Processing Record 414 | Semikarakorsk
# http://api.openweathermap.org/data/2.5/weather?&q=semikarakorsk
# Processing Record 415 | Oruzgan
# http://api.openweathermap.org/data/2.5/weather?&q=uruzgan
# Processing Record 416 | Ugento
# http://api.openweathermap.org/data/2.5/weather?&q=ugento
# Processing Record 417 | Cedar City
# http://api.openweathermap.org/data/2.5/weather?&q=cedar city
# Processing Record 418 | San Juan
# http://api.openweathermap.org/data/2.5/weather?&q=san juan
# Processing Record 419 | Cambrils
# http://api.openweathermap.org/data/2.5/weather?&q=cambrils
# Processing Record 420 | Acapulco de Juárez
# http://api.openweathermap.org/data/2.5/weather?&q=acapulco
# Processing Record 421 | Sītāmau
# http://api.openweathermap.org/data/2.5/weather?&q=sitamau
# Processing Record 422 | Sharjah city
# http://api.openweathermap.org/data/2.5/weather?&q=sharjah
# Processing Record 423 | Blackfoot
# http://api.openweathermap.org/data/2.5/weather?&q=blackfoot
# Processing Record 424 | Obregon
# http://api.openweathermap.org/data/2.5/weather?&q=obregon
# temaraia not found: Skipping
# Processing Record 425 | Dergachi
# http://api.openweathermap.org/data/2.5/weather?&q=dergachi
# Processing Record 426 | Mareeba
# http://api.openweathermap.org/data/2.5/weather?&q=mareeba
# Processing Record 427 | Correia Pinto
# http://api.openweathermap.org/data/2.5/weather?&q=correia pinto
# Processing Record 428 | Mabaruma
# http://api.openweathermap.org/data/2.5/weather?&q=mabaruma
# Processing Record 429 | Äänekoski
# http://api.openweathermap.org/data/2.5/weather?&q=aanekoski
# kerteh not found: Skipping
# Processing Record 430 | Takoradze
# http://api.openweathermap.org/data/2.5/weather?&q=takoradi
# Processing Record 431 | Panzhihua
# http://api.openweathermap.org/data/2.5/weather?&q=panzhihua
# Processing Record 432 | Victor Harbor
# http://api.openweathermap.org/data/2.5/weather?&q=victor harbor
# Processing Record 433 | Tunceli
# http://api.openweathermap.org/data/2.5/weather?&q=tunceli
# Processing Record 434 | Palu
# http://api.openweathermap.org/data/2.5/weather?&q=palu
# Processing Record 435 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?&q=aklavik
# Processing Record 436 | Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?&q=quatre cocos
# Processing Record 437 | Tabuk
# http://api.openweathermap.org/data/2.5/weather?&q=tabuk
# Processing Record 438 | Muzhi
# http://api.openweathermap.org/data/2.5/weather?&q=muzhi
# Processing Record 439 | Beloha
# http://api.openweathermap.org/data/2.5/weather?&q=beloha
# Processing Record 440 | Bahir Dar
# http://api.openweathermap.org/data/2.5/weather?&q=bahir dar
# Processing Record 441 | Isangel
# http://api.openweathermap.org/data/2.5/weather?&q=isangel
# Processing Record 442 | Matagami
# http://api.openweathermap.org/data/2.5/weather?&q=matagami
# Processing Record 443 | Tual
# http://api.openweathermap.org/data/2.5/weather?&q=tual
# Processing Record 444 | Touros
# http://api.openweathermap.org/data/2.5/weather?&q=touros
# ust-bolsheretsk not found: Skipping
# palabuhanratu not found: Skipping
# Processing Record 445 | Dingle
# http://api.openweathermap.org/data/2.5/weather?&q=dingle
# Processing Record 446 | Vilyuysk
# http://api.openweathermap.org/data/2.5/weather?&q=vilyuysk
# Processing Record 447 | Chiredzi
# http://api.openweathermap.org/data/2.5/weather?&q=chiredzi
# Processing Record 448 | Charlestown
# http://api.openweathermap.org/data/2.5/weather?&q=charlestown
# Processing Record 449 | Ust-Tsilma
# http://api.openweathermap.org/data/2.5/weather?&q=ust-tsilma
# Processing Record 450 | Kenai
# http://api.openweathermap.org/data/2.5/weather?&q=kenai
# Processing Record 451 | Hirara
# http://api.openweathermap.org/data/2.5/weather?&q=hirara
# Processing Record 452 | Kosh-Agach
# http://api.openweathermap.org/data/2.5/weather?&q=kosh-agach
# Processing Record 453 | Rawson
# http://api.openweathermap.org/data/2.5/weather?&q=rawson
# Processing Record 454 | Aswān
# http://api.openweathermap.org/data/2.5/weather?&q=aswan
# Processing Record 455 | Kisangani
# http://api.openweathermap.org/data/2.5/weather?&q=kisangani
# Processing Record 456 | Porbandar
# http://api.openweathermap.org/data/2.5/weather?&q=porbandar
# Processing Record 457 | Risør
# http://api.openweathermap.org/data/2.5/weather?&q=risor
# Processing Record 458 | Makat
# http://api.openweathermap.org/data/2.5/weather?&q=makat
# Processing Record 459 | Rawlins
# http://api.openweathermap.org/data/2.5/weather?&q=rawlins
# Processing Record 460 | Chivay
# http://api.openweathermap.org/data/2.5/weather?&q=chivay
# Processing Record 461 | Nizhnyaya Omka
# http://api.openweathermap.org/data/2.5/weather?&q=nizhnyaya omka
# Processing Record 462 | Alofi
# http://api.openweathermap.org/data/2.5/weather?&q=alofi
# Processing Record 463 | Buchanan
# http://api.openweathermap.org/data/2.5/weather?&q=buchanan
# Processing Record 464 | Helong
# http://api.openweathermap.org/data/2.5/weather?&q=helong
# Processing Record 465 | Pevek
# http://api.openweathermap.org/data/2.5/weather?&q=pevek
# Processing Record 466 | Bereda
# http://api.openweathermap.org/data/2.5/weather?&q=bereda
# Processing Record 467 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?&q=port lincoln
# Processing Record 468 | The Valley
# http://api.openweathermap.org/data/2.5/weather?&q=the valley
# Processing Record 469 | Colonia Nueva Germania
# http://api.openweathermap.org/data/2.5/weather?&q=nueva germania
# Processing Record 470 | Havre-St-Pierre
# http://api.openweathermap.org/data/2.5/weather?&q=havre-saint-pierre
# Processing Record 471 | Manado
# http://api.openweathermap.org/data/2.5/weather?&q=manado
# Processing Record 472 | Hell
# http://api.openweathermap.org/data/2.5/weather?&q=hell
# Processing Record 473 | Florø
# http://api.openweathermap.org/data/2.5/weather?&q=floro
# Processing Record 474 | Shakawe
# http://api.openweathermap.org/data/2.5/weather?&q=shakawe
# Processing Record 475 | Juàzeirinho
# http://api.openweathermap.org/data/2.5/weather?&q=juazeirinho
# Processing Record 476 | Luyang
# http://api.openweathermap.org/data/2.5/weather?&q=luyang
# Processing Record 477 | Pereslavl'-Zalesskiy
# http://api.openweathermap.org/data/2.5/weather?&q=pereslavl-zalesskiy
# Processing Record 478 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?&q=caravelas
# Processing Record 479 | Raudeberg
# http://api.openweathermap.org/data/2.5/weather?&q=raudeberg
# Processing Record 480 | Askiz
# http://api.openweathermap.org/data/2.5/weather?&q=askiz
# Processing Record 481 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?&q=okhotsk
# Processing Record 482 | Sūsangerd
# http://api.openweathermap.org/data/2.5/weather?&q=susangerd
# Processing Record 483 | San Rafael
# http://api.openweathermap.org/data/2.5/weather?&q=san rafael
# Processing Record 484 | Puerto Madero
# http://api.openweathermap.org/data/2.5/weather?&q=puerto madero
# Processing Record 485 | Tavistock
# http://api.openweathermap.org/data/2.5/weather?&q=tavistock
# Processing Record 486 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?&q=cockburn town
# koyilandi not found: Skipping
# Processing Record 487 | Olinda
# http://api.openweathermap.org/data/2.5/weather?&q=olinda
# Processing Record 488 | Urzhum
# http://api.openweathermap.org/data/2.5/weather?&q=urzhum
# Processing Record 489 | Staropyshminsk
# http://api.openweathermap.org/data/2.5/weather?&q=staropyshminsk
# Processing Record 490 | Broken Hill
# http://api.openweathermap.org/data/2.5/weather?&q=broken hill
# Processing Record 491 | Gatton
# http://api.openweathermap.org/data/2.5/weather?&q=gatton
# Processing Record 492 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?&q=port hedland
# Processing Record 493 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?&q=lorengau
# Processing Record 494 | Savalou
# http://api.openweathermap.org/data/2.5/weather?&q=savalou
# Processing Record 495 | Morros
# http://api.openweathermap.org/data/2.5/weather?&q=morros
# Processing Record 496 | Dzaoudzi
# http://api.openweathermap.org/data/2.5/weather?&q=dzaoudzi
# Processing Record 497 | Tabou
# http://api.openweathermap.org/data/2.5/weather?&q=tabou
# Processing Record 498 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?&q=srednekolymsk
# Processing Record 499 | Ibrā’
# http://api.openweathermap.org/data/2.5/weather?&q=ibra
# Processing Record 500 | Ola
# http://api.openweathermap.org/data/2.5/weather?&q=ola
# Processing Record 501 | Tura
# http://api.openweathermap.org/data/2.5/weather?&q=tura
# Processing Record 502 | Acajutla
# http://api.openweathermap.org/data/2.5/weather?&q=acajutla
# Processing Record 503 | Colac
# http://api.openweathermap.org/data/2.5/weather?&q=colac
# Processing Record 504 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?&q=half moon bay
# Processing Record 505 | Haapiti
# http://api.openweathermap.org/data/2.5/weather?&q=haapiti
# Processing Record 506 | Tokur
# http://api.openweathermap.org/data/2.5/weather?&q=tokur
# Processing Record 507 | Keti Bandar
# http://api.openweathermap.org/data/2.5/weather?&q=keti bandar
# Processing Record 508 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?&q=kavaratti
# Processing Record 509 | Porto Torres
# http://api.openweathermap.org/data/2.5/weather?&q=porto torres
# Processing Record 510 | Salisbury
# http://api.openweathermap.org/data/2.5/weather?&q=salisbury
# Processing Record 511 | Boshnyakovo
# http://api.openweathermap.org/data/2.5/weather?&q=boshnyakovo
# liapades not found: Skipping
# Processing Record 512 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?&q=namatanai
# Processing Record 513 | Baixa Grande
# http://api.openweathermap.org/data/2.5/weather?&q=baixa grande
# Processing Record 514 | Ibotirama
# http://api.openweathermap.org/data/2.5/weather?&q=ibotirama
# Processing Record 515 | Djenné
# http://api.openweathermap.org/data/2.5/weather?&q=djenne
# Processing Record 516 | Shenjiamen
# http://api.openweathermap.org/data/2.5/weather?&q=shenjiamen
# Processing Record 517 | Vysokaya Gora
# http://api.openweathermap.org/data/2.5/weather?&q=vysokaya gora
# Processing Record 518 | Mersing
# http://api.openweathermap.org/data/2.5/weather?&q=mersing
# Processing Record 519 | Cap Malheureux
# http://api.openweathermap.org/data/2.5/weather?&q=cap malheureux
# Processing Record 520 | Jizan
# http://api.openweathermap.org/data/2.5/weather?&q=jizan
# Processing Record 521 | Santiago de Cuba
# http://api.openweathermap.org/data/2.5/weather?&q=santiago de cuba
# Processing Record 522 | Verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?&q=verkhnevilyuysk
# Processing Record 523 | Zaraza
# http://api.openweathermap.org/data/2.5/weather?&q=zaraza
# Processing Record 524 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?&q=cayenne
# Processing Record 525 | Mandalgovi
# http://api.openweathermap.org/data/2.5/weather?&q=mandalgovi
# Processing Record 526 | Lüderitz
# http://api.openweathermap.org/data/2.5/weather?&q=luderitz
# Processing Record 527 | Inuvik
# http://api.openweathermap.org/data/2.5/weather?&q=inuvik
# Processing Record 528 | Sucúa
# http://api.openweathermap.org/data/2.5/weather?&q=sucua
# Processing Record 529 | Manta
# http://api.openweathermap.org/data/2.5/weather?&q=manta
# Processing Record 530 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?&q=bonavista
# Processing Record 531 | Sena Madureira
# http://api.openweathermap.org/data/2.5/weather?&q=sena madureira
# Processing Record 532 | Santarém
# http://api.openweathermap.org/data/2.5/weather?&q=santarem
# Processing Record 533 | Williams Lake
# http://api.openweathermap.org/data/2.5/weather?&q=williams lake
# Processing Record 534 | São José dos Pinhais
# http://api.openweathermap.org/data/2.5/weather?&q=sao jose dos pinhais
# brajrajnagar not found: Skipping
# Processing Record 535 | Samarai
# http://api.openweathermap.org/data/2.5/weather?&q=samarai
# Processing Record 536 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?&q=saint-pierre
# Processing Record 537 | Leeton
# http://api.openweathermap.org/data/2.5/weather?&q=leeton
# Processing Record 538 | Reyes
# http://api.openweathermap.org/data/2.5/weather?&q=reyes
# Processing Record 539 | Sangar
# http://api.openweathermap.org/data/2.5/weather?&q=sangar
# Processing Record 540 | Ushtobe
# http://api.openweathermap.org/data/2.5/weather?&q=ushtobe
# Processing Record 541 | Keskin
# http://api.openweathermap.org/data/2.5/weather?&q=keskin
# Processing Record 542 | Ponferrada
# http://api.openweathermap.org/data/2.5/weather?&q=ponferrada
# Processing Record 543 | Bhadrak
# http://api.openweathermap.org/data/2.5/weather?&q=bhadrak
# Processing Record 544 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?&q=guerrero negro
# tapaua not found: Skipping
# Processing Record 545 | Soe
# http://api.openweathermap.org/data/2.5/weather?&q=soe
# Processing Record 546 | Potenza
# http://api.openweathermap.org/data/2.5/weather?&q=potenza
# Processing Record 547 | Bow Island
# http://api.openweathermap.org/data/2.5/weather?&q=bow island
# Processing Record 548 | Hofn
# http://api.openweathermap.org/data/2.5/weather?&q=hofn
# Processing Record 549 | Pishin
# http://api.openweathermap.org/data/2.5/weather?&q=pishin
# Processing Record 550 | Wenzhou
# http://api.openweathermap.org/data/2.5/weather?&q=wenzhou
# Processing Record 551 | Jalu
# http://api.openweathermap.org/data/2.5/weather?&q=jalu
# ahumada not found: Skipping
# Processing Record 552 | Santa Cruz Cabrália
# http://api.openweathermap.org/data/2.5/weather?&q=santa cruz cabralia
# Processing Record 553 | Tignère
# http://api.openweathermap.org/data/2.5/weather?&q=tignere
# Processing Record 554 | Mahajanga
# http://api.openweathermap.org/data/2.5/weather?&q=mahajanga
# Processing Record 555 | Alyangula
# http://api.openweathermap.org/data/2.5/weather?&q=alyangula
# Processing Record 556 | Salta
# http://api.openweathermap.org/data/2.5/weather?&q=salta
# Processing Record 557 | Chipinge
# http://api.openweathermap.org/data/2.5/weather?&q=chipinge
# Processing Record 558 | Batagay-Alyta
# http://api.openweathermap.org/data/2.5/weather?&q=batagay-alyta
# Processing Record 559 | Tomatlán
# http://api.openweathermap.org/data/2.5/weather?&q=tomatlan
# Processing Record 560 | Kailua
# http://api.openweathermap.org/data/2.5/weather?&q=kailua
# Processing Record 561 | Malakal
# http://api.openweathermap.org/data/2.5/weather?&q=malakal
# Processing Record 562 | Khiri Mat
# http://api.openweathermap.org/data/2.5/weather?&q=khiri mat
# Processing Record 563 | Rome
# http://api.openweathermap.org/data/2.5/weather?&q=roma
# Processing Record 564 | Ogaminana
# http://api.openweathermap.org/data/2.5/weather?&q=ogaminana
# Processing Record 565 | Kambove
# http://api.openweathermap.org/data/2.5/weather?&q=kambove
# mys shmidta not found: Skipping
# Processing Record 566 | Rocky Mountain House
# http://api.openweathermap.org/data/2.5/weather?&q=rocky mountain house
# Processing Record 567 | Dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?&q=dhidhdhoo
# Processing Record 568 | Batticaloa
# http://api.openweathermap.org/data/2.5/weather?&q=batticaloa
# Processing Record 569 | Ndjolé
# http://api.openweathermap.org/data/2.5/weather?&q=ndjole
# Processing Record 570 | Pindiga
# http://api.openweathermap.org/data/2.5/weather?&q=pindiga
# Processing Record 571 | Esperance
# http://api.openweathermap.org/data/2.5/weather?&q=esperance
# Processing Record 572 | Kiunga
# http://api.openweathermap.org/data/2.5/weather?&q=kiunga
# Processing Record 573 | Verkh-Usugli
# http://api.openweathermap.org/data/2.5/weather?&q=verkh-usugli
# --------------------------------
# Weather data found for 633 cities.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Export data into a .csv
weather_data = pd.DataFrame({'City': city_name, 
                             'Temperature': temp, 
                             'Latitude': lat, 
                             'Longitude': lon,
                             'Humidity': humidity, 
                             'Cloudiness': cloudiness, 
                             'Wind Speed': wind_speed,
                             'Country': country,
                             'Date': date})

# Output File (CSV)
weather_data.to_csv('../output_data/weather_data.csv', index = False)

# Display data in DataFrame
weather_data.count()
# Out:
# City           573
# Temperature    573
# Latitude       573
# Longitude      573
# Humidity       573
# Cloudiness     573
# Wind Speed     573
# Country        573
# Date           573
# dtype: int64

# %%
weather_data.head()
# Out:
#           City  Temperature  Latitude  Longitude  Humidity  Cloudiness  \
# 0      Husavik        46.40     66.04     -17.34        81          75
# 1  George Town        78.84      5.41     100.34        94          20
# 2      Rikitea        68.68    -23.12    -134.97        62          45
# 3       Nabire        83.50     -3.37     135.48        67          34
# 4    Busselton        46.87    -33.65     115.33        99          36
#
#    Wind Speed Country        Date
# 0        3.36      IS  1595204416
# 1        4.45      MY  1595204424
# 2       11.03      PF  1595204370
# 3        1.59      ID  1595204317
# 4        3.00      AU  1595204424

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_data.sort_values(['Humidity'], ascending = False)
#there are no cities with Humidity > 100%
# Out:
#              City  Temperature  Latitude  Longitude  Humidity  Cloudiness  \
# 452        Rawson        42.80    -43.30     -65.10       100          90
# 407        Padang        73.40     -0.95     100.35       100          20
# 208         Ancud        47.53    -41.87     -73.82       100          90
# 46         Aykhal        53.60     66.00     111.50       100          90
# 206     Cape Town        55.96    -33.93      18.42       100          40
# ..            ...          ...       ...        ...       ...         ...
# 458       Rawlins        86.97     41.79    -107.24        10           1
# 391    Ridgecrest       105.12     35.62    -117.67         8          75
# 199  Saint George       105.15     37.10    -113.58         7           1
# 16     Winnemucca       100.40     40.97    -117.74         6           1
# 416    Cedar City        95.00     37.68    -113.06         5           1
#
#      Wind Speed Country        Date
# 452        8.05      AR  1595204415
# 407        2.24      ID  1595204752
# 208        4.70      CL  1595204615
# 46         8.95      RU  1595204452
# 206        9.17      ZA  1595204597
# ..          ...     ...         ...
# 458       25.28      US  1595204719
# 391       16.11      US  1595204749
# 199       19.46      US  1595204619
# 16        13.87      US  1595204426
# 416        9.17      US  1595204673
#
# [573 rows x 9 columns]

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#        City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  pimentel  -6.84  -79.93     66.20        29          75        5.82
# 1  victoria  22.29  114.16     69.01        88          40       18.34
# 2    padang  -0.95  100.35     79.90        75          99        1.63
# 3    hasaki  35.73  140.83     55.00       100          75        4.70
# 4   kahului  20.89 -156.47     70.00        88           1        7.63
#
#   Country        Date
# 0      PE  1585764415
# 1      HK  1585764288
# 2      ID  1585764115
# 3      JP  1585764415
# 4      US  1585764415

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data['Latitude'], weather_data['Temperature'], marker = 'o', facecolors='aqua', alpha = 0.6, edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title('Latitude vs. Temperature (07/16/20)')
plt.grid(True)
plt.savefig('latvstemp-scatter.png')
plt.show()

# %%
# this plot is showing that as you get closer to the equator (latitude = 0) the temperature increases

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data['Latitude'], weather_data['Humidity'], marker = 'o', facecolors='aqua', alpha = 0.6, edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Latitude vs. Humidity (07/16/20)')
plt.grid(True)
plt.savefig('latvshum-scatter.png')
plt.show()

# %%
# this plot is showing that humidity doesn't really depend on latitude

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data['Latitude'], weather_data['Cloudiness'], marker = 'o', facecolors='aqua', alpha = 0.6, edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Latitude vs. Cloudiness (07/16/20)')
plt.grid(True)
plt.savefig('latvscloud-scatter.png')
plt.show()

# %%
# this graph is demonstrating that cloudiness does not really depend on latitude..  But it does seem liek there is a little more clouds at higher latitudes (the uper right quadrant of the graph).

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data['Latitude'], weather_data['Wind Speed'], marker = 'o', facecolors='aqua', alpha = 0.6, edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Latitude vs. Wind Speed (07/16/20)')
plt.grid(True)
plt.savefig('latvswind-scatter.png')
plt.show()

# %%
# this graph shows the relaltionship between wind speed and latitude and it kind of looks like wind speed does not depend on latitude

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hem = weather_data.loc[weather_data["Latitude"] >= 0.0]
northern_hem.reset_index

southern_hem = weather_data.loc[weather_data["Latitude"] < 0.0]
southern_hem.reset_index
northern_hem
# Out:
#                      City  Temperature  Latitude  Longitude  Humidity  \
# 0                 Husavik        46.40     66.04     -17.34        81
# 1             George Town        78.84      5.41     100.34        94
# 7                 Qaanaaq        47.70     77.48     -69.36        69
# 9                   Catió        76.89     11.28     -15.25        90
# 10                 Dongli        87.80     23.57     116.82        70
# ..                    ...          ...       ...        ...       ...
# 565  Rocky Mountain House        63.82     52.37    -114.92        76
# 566             Dhidhdhoo        81.64      6.88      73.10        81
# 567            Batticaloa        80.37      7.71      81.69        77
# 569               Pindiga        72.28      9.98      10.93        94
# 572          Verkh-Usugli        51.96     52.70     115.17        81
#
#      Cloudiness  Wind Speed Country        Date
# 0            75        3.36      IS  1595204416
# 1            20        4.45      MY  1595204424
# 7            98        2.28      GL  1595204394
# 9           100        7.56      GW  1595204425
# 10           20        2.24      CN  1595204425
# ..          ...         ...     ...         ...
# 565          95        4.50      CA  1595204676
# 566         100       25.34      MV  1595204860
# 567          99        4.43      LK  1595204637
# 569          98        9.24      NG  1595204860
# 572         100        8.10      RU  1595204659
#
# [391 rows x 9 columns]

# %%
southern_hem
# Out:
#               City  Temperature  Latitude  Longitude  Humidity  Cloudiness  \
# 2          Rikitea        68.68    -23.12    -134.97        62          45
# 3           Nabire        83.50     -3.37     135.48        67          34
# 4        Busselton        46.87    -33.65     115.33        99          36
# 5    Mar del Plata        52.47    -38.00     -57.56        87          90
# 6    Florianópolis        66.20    -27.61     -48.50        93           0
# ..             ...          ...       ...        ...       ...         ...
# 556       Chipinge        47.37    -20.19      32.62        98           4
# 564        Kambove        49.44    -10.88      26.60        74           0
# 568         Ndjolé        72.95     -0.18      10.76        90         100
# 570      Esperance        53.60    -33.87     121.90        66          90
# 571         Kiunga        77.45     -6.12     141.29        88          98
#
#      Wind Speed Country        Date
# 2         11.03      PF  1595204370
# 3          1.59      ID  1595204317
# 4          3.00      AU  1595204424
# 5         13.87      AR  1595204287
# 6         14.99      BR  1595204425
# ..          ...     ...         ...
# 556        4.32      ZW  1595204858
# 564        6.26      CD  1595204859
# 568        4.32      GA  1595204860
# 570        4.70      AU  1595204610
# 571        4.07      PG  1595204860
#
# [182 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = northern_hem['Latitude']
y = northern_hem['Temperature']
plt.scatter(x,y, marker = 'o', facecolors='aqua', alpha = 0.6, edgecolors='black')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = northern_hem['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_square = rvalue**2
plt.plot(x,regress_values,"black")
plt.annotate(line_eq,(10,50),fontsize = 15, color="black")
plt.annotate(f"r^2= {r_square}",(10,42),fontsize = 15, color="black")
plt.title("Northern Hemisphere Temperature vs Latitude")
plt.ylabel('Temperature (F)')
plt.xlabel('Latitude')
plt.savefig("Images/northern_temp_lat.png")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = southern_hem['Latitude']
y = southern_hem['Temperature']
plt.scatter(x,y, marker = 'o', facecolors='aqua', alpha = 0.6, edgecolors='black')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = southern_hem['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_square = rvalue**2
plt.plot(x,regress_values,"black")
plt.annotate(line_eq,(-40,40),fontsize = 15, color="black")
plt.annotate(f"r^2= {r_square_s}",(-40,32),fontsize = 15, color="black")
plt.title("Southern Hemisphere Temperature vs Latitude")
plt.ylabel('Temperature (F)')
plt.xlabel('Latitude')
plt.savefig("Images/southern_temp_lat.png")

# %%
#In the Northern hemisphere there is a negative correlation between temperature and latitude which turns into a positive correlation in the southern hemisphere because the closer you get to the equator coming from both directions, it gets hotter.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = northern_hem['Latitude']
y = northern_hem['Temperature']
plt.scatter(x,y, marker = 'o', facecolors='aqua', alpha = 0.6, edgecolors='black')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = northern_hem['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_square = rvalue**2
plt.plot(x,regress_values,"black")
plt.annotate(line_eq,(42,19.9),fontsize = 15, color="black")
plt.annotate(f"r^2= {r_square}",(41,19.85),fontsize = 15, color="black")
plt.title("Northern Hemisphere Humidity vs Latitude")
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.savefig("Images/northern_temp_hum.png")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = southern_hem['Latitude']
y = southern_hem['Humidity']
plt.scatter(x,y, marker = 'o', facecolors='aqua', alpha = 0.6, edgecolors='black')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = southern_hem['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_square = rvalue**2
plt.plot(x,regress_values,"black")
plt.annotate(line_eq,(-50,40),fontsize = 15, color="black")
plt.annotate(f"r^2= {r_square}",(-50,30),fontsize = 15, color="black")
plt.title("Southern Hemisphere Humidity vs Latitude")
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.savefig("Images/southern_temp_hum.png")

# %%
# In the Northern hemisphere there is a negative correlation between latitude and humidity, the farther south you go, the more humid it becomes. 
# However, this correlation does not persist in the Southern hemisphere because there is much lower land mass

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = northern_hem['Latitude']
y = northern_hem['Cloudiness']
plt.scatter(x,y, marker = 'o', facecolors='aqua', alpha = 0.6, edgecolors='black')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = northern_hem['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_square = rvalue**2
plt.plot(x,regress_values,"black")
plt.annotate(line_eq,(10,40),fontsize = 15, color="black")
plt.annotate(f"r^2= {r_square}",(10,30),fontsize = 15, color="black")
plt.title("Northern Hemisphere Cloudiness vs Latitude")
plt.ylabel('Cloudiness')
plt.xlabel('Latitude')
plt.savefig("Images/northern_temp_cloud.png")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = southern_hem['Latitude']
y = southern_hem['Cloudiness']
plt.scatter(x,y, marker = 'o', facecolors='aqua', alpha = 0.6, edgecolors='black')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = southern_hem['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_square = rvalue**2
plt.plot(x,regress_values,"black")
plt.annotate(line_eq,(-50,30),fontsize = 15, color="black")
plt.annotate(f"r^2= {r_square}",(-50,20),fontsize = 15, color="black")
plt.title("Southern Hemisphere Cloudiness vs Latitude")
plt.ylabel('Cloudiness')
plt.xlabel('Latitude')
plt.savefig("Images/southern_temp_cloud.png")

# %%
# There does not seem to be a correlation between latitude and cloudiness

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = northern_hem['Latitude']
y = northern_hem['Wind Speed']
plt.scatter(x,y, marker = 'o', facecolors='aqua', alpha = 0.6, edgecolors='black')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = northern_hem['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_square = rvalue**2
plt.plot(x,regress_values,"black")
plt.annotate(line_eq,(10,25),fontsize = 15, color="black")
plt.annotate(f"r^2= {r_square}",(10,20),fontsize = 15, color="black")
plt.title("Northern Hemisphere Wind Speed vs Latitude")
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.savefig("Images/northern_temp_wind.png")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = southern_hem['Latitude']
y = southern_hem['Wind Speed']
plt.scatter(x,y, marker = 'o', facecolors='aqua', alpha = 0.6, edgecolors='black')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = southern_hem['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_square = rvalue**2
plt.plot(x,regress_values,"black")
plt.annotate(line_eq,(-50,20),fontsize = 15, color="black")
plt.annotate(f"r^2= {r_square}",(-50,15),fontsize = 15, color="black")
plt.title("Southern Hemisphere Wind Speed vs Latitude")
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.savefig("Images/southern_temp_wind.png")

# %%
# There does not seem to be a correlation between Latitude and Wind Speed
